# %%
import sys #access to system parameters https://docs.python.org/3/library/sys.html

import pandas as pd #collection of functions for data processing and analysis modeled after R dataframes with SQL like features

import matplotlib #collection of functions for scientific and publication-ready visualization

import numpy as np #foundational package for scientific computing

import scipy as sp #collection of functions for scientific computing and advance mathematics

import IPython
from IPython import display #pretty printing of dataframes in Jupyter notebook

import sklearn #collection of machine learning algorithms

#misc libraries
import random
import time
import datetime as dt

#ignore warnings
import warnings
warnings.filterwarnings('ignore')
print('-'*25)

import featuretools as ft
from sklearn.feature_extraction.text import CountVectorizer
# Out:
# -------------------------

# %%
#Common Model Algorithms
from sklearn import svm, tree, linear_model, neighbors, naive_bayes, ensemble, discriminant_analysis, gaussian_process
import xgboost as xgb

#Common Model Helpers
from sklearn.preprocessing import OneHotEncoder, LabelEncoder
from sklearn import feature_selection
from sklearn import model_selection
from sklearn.model_selection import train_test_split

from sklearn import metrics

#Visualization
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.pylab as pylab
import seaborn as sns
from pandas.tools.plotting import scatter_matrix

#Configure Visualization Defaults
#%matplotlib inline = show plots in Jupyter Notebook browser
# %matplotlib inline
mpl.style.use('ggplot')
sns.set_style('white')
pylab.rcParams['figure.figsize'] = 12,8

# %%
data_raw = pd.read_csv('events_up_to_01062018.csv')
data_val = pd.read_csv('labels_training_set.csv')

# %%
data_raw.head()
# Out:
#              timestamp           event    person  url      sku  \
# 0  2018-05-18 00:11:59  viewed product  4886f805  NaN   9288.0
# 1  2018-05-18 00:11:27  viewed product  ad93850f  NaN    304.0
# 2  2018-05-18 00:11:16  viewed product  0297fc1e  NaN   6888.0
# 3  2018-05-18 00:11:14  viewed product  2d681dd8  NaN  11890.0
# 4  2018-05-18 00:11:09  viewed product  cccea85e  NaN   7517.0
#
#                      model  condition storage           color skus  \
# 0  Samsung Galaxy J7 Prime  Excelente    32GB         Dourado  NaN
# 1                iPhone 5s  Muito Bom    32GB  Cinza espacial  NaN
# 2                iPhone 6S  Muito Bom    64GB        Prateado  NaN
# 3                 iPhone 7        Bom   128GB        Vermelho  NaN
# 4              LG G4 H818P  Excelente    32GB          Branco  NaN
#
#         ...       search_engine channel new_vs_returning city region country  \
# 0       ...                 NaN     NaN              NaN  NaN    NaN     NaN
# 1       ...                 NaN     NaN              NaN  NaN    NaN     NaN
# 2       ...                 NaN     NaN              NaN  NaN    NaN     NaN
# 3       ...                 NaN     NaN              NaN  NaN    NaN     NaN
# 4       ...                 NaN     NaN              NaN  NaN    NaN     NaN
#
#   device_type screen_resolution operating_system_version browser_version
# 0         NaN               NaN                      NaN             NaN
# 1         NaN               NaN                      NaN             NaN
# 2         NaN               NaN                      NaN             NaN
# 3         NaN               NaN                      NaN             NaN
# 4         NaN               NaN                      NaN             NaN
#
# [5 rows x 23 columns]

# %%
df_labels = data_val.copy(deep=True) 
df = data_raw.copy(deep=True)

# %%
pd.set_option('display.max_columns', 23)

# %%
df.describe(include= 'all')
# Out:
#                   timestamp           event    person     url           sku  \
# count               2341681         2341681   2341681  191131  1.320530e+06
# unique              1490912              11     38829     248           NaN
# top     2018-05-31 01:59:16  viewed product  c76b8417       /           NaN
# freq                     14         1248124      4438   64187           NaN
# mean                    NaN             NaN       NaN     NaN  6.899178e+03
# std                     NaN             NaN       NaN     NaN  4.028042e+03
# min                     NaN             NaN       NaN     NaN  7.100000e+01
# 25%                     NaN             NaN       NaN     NaN  2.929000e+03
# 50%                     NaN             NaN       NaN     NaN  7.057000e+03
# 75%                     NaN             NaN       NaN     NaN  1.001400e+04
# max                     NaN             NaN       NaN     NaN  1.748500e+04
#
#            model condition  storage    color  \
# count    1321513   1320530  1320530  1320530
# unique       208         5        8       63
# top     iPhone 6       Bom     16GB    Preto
# freq      107262    547617   442096   314925
# mean         NaN       NaN      NaN      NaN
# std          NaN       NaN      NaN      NaN
# min          NaN       NaN      NaN      NaN
# 25%          NaN       NaN      NaN      NaN
# 50%          NaN       NaN      NaN      NaN
# 75%          NaN       NaN      NaN      NaN
# max          NaN       NaN      NaN      NaN
#
#                                                      skus search_term  \
# count                                              505949      113763
# unique                                              52267       10964
# top     2820,6706,6720,2750,6649,7251,6663,12604,7224,...      Iphone
# freq                                                 2606        2577
# mean                                                  NaN         NaN
# std                                                   NaN         NaN
# min                                                   NaN         NaN
# 25%                                                   NaN         NaN
# 50%                                                   NaN         NaN
# 75%                                                   NaN         NaN
# max                                                   NaN         NaN
#
#              staticpage campaign_source search_engine channel  \
# count             11201          191286        106406  204069
# unique               14              23             4       7
# top     CustomerService          google        Google    Paid
# freq               5239          123354        105195   91753
# mean                NaN             NaN           NaN     NaN
# std                 NaN             NaN           NaN     NaN
# min                 NaN             NaN           NaN     NaN
# 25%                 NaN             NaN           NaN     NaN
# 50%                 NaN             NaN           NaN     NaN
# 75%                 NaN             NaN           NaN     NaN
# max                 NaN             NaN           NaN     NaN
#
#        new_vs_returning     city     region country device_type  \
# count            204069   204069     204069  204069      204069
# unique                2     2206        122      51           4
# top           Returning  Unknown  Sao Paulo  Brazil  Smartphone
# freq             165827    36866      57304  197699      103502
# mean                NaN      NaN        NaN     NaN         NaN
# std                 NaN      NaN        NaN     NaN         NaN
# min                 NaN      NaN        NaN     NaN         NaN
# 25%                 NaN      NaN        NaN     NaN         NaN
# 50%                 NaN      NaN        NaN     NaN         NaN
# 75%                 NaN      NaN        NaN     NaN         NaN
# max                 NaN      NaN        NaN     NaN         NaN
#
#        screen_resolution operating_system_version browser_version
# count             204066                   204069          204069
# unique               393                      131             366
# top              360x640               Windows 7      Chrome 66.0
# freq               73234                    46648           57953
# mean                 NaN                      NaN             NaN
# std                  NaN                      NaN             NaN
# min                  NaN                      NaN             NaN
# 25%                  NaN                      NaN             NaN
# 50%                  NaN                      NaN             NaN
# 75%                  NaN                      NaN             NaN
# max                  NaN                      NaN             NaN

# %%
persons = (df.drop_duplicates('person'))['person'].to_frame()
persons_to_train = df_labels['person'].to_frame()
persons_to_predict = persons.loc[~persons['person'].isin(persons_to_train['person'])]


print(persons_to_train.shape)
print(persons_to_predict.shape)
# Out:
# (19414, 1)
# (19415, 1)

# %%
df['timestamp'] = pd.to_datetime(df['timestamp'])
df = df.sort_values(['timestamp','event'])
df = df.reset_index(drop=True)

# %%
df_dates_per_month = persons
df_months = df
df_months['month'] = df_months['timestamp'].dt.month

# %%
#for x in range(1,6):
#    df_month = df_months.loc[df['month'] == x]
 #   df_dates = df_month.groupby('person').agg({'timestamp':['max', 'min']}).reset_index()
  #  df_dates.columns = ['person', 'last month '+str(x), 'first month '+ str(x)]
   # df_dates['diferencia'+str(x)] = (df_dates['last month '+str(x)] - df_dates['first month '+ str(x)]).dt.days
    #print(df_dates.head(1))
     #df_dates_per_month = df_dates_per_month.merge(df_dates, on = 'person', how='left')

# %%
df_month = df_months.loc[df_months['month'] == 5]
df_month = df_month.loc[df_month['event'] == 'checkout'].reset_index(drop=True)
df_month['session'] = df_month.index
df_month.head()
# Out:
#             timestamp     event    person  url     sku              model  \
# 0 2018-05-01 00:01:40  checkout  0ef8e58a  NaN  2829.0           iPhone 6
# 1 2018-05-01 00:02:47  checkout  754cd2b0  NaN  9944.0           iPhone 7
# 2 2018-05-01 00:08:18  checkout  72d959bc  NaN  6369.0  Samsung Galaxy J5
# 3 2018-05-01 00:10:13  checkout  72d959bc  NaN  6369.0  Samsung Galaxy J5
# 4 2018-05-01 00:17:56  checkout  66a98d8f  NaN   291.0          iPhone 5s
#
#    condition storage        color skus search_term   ...   channel  \
# 0        Bom    16GB     Prateado  NaN         NaN   ...       NaN
# 1        Bom   128GB  Preto Matte  NaN         NaN   ...       NaN
# 2  Excelente    16GB      Dourado  NaN         NaN   ...       NaN
# 3  Excelente    16GB      Dourado  NaN         NaN   ...       NaN
# 4  Excelente    16GB      Dourado  NaN         NaN   ...       NaN
#
#   new_vs_returning city region country device_type screen_resolution  \
# 0              NaN  NaN    NaN     NaN         NaN               NaN
# 1              NaN  NaN    NaN     NaN         NaN               NaN
# 2              NaN  NaN    NaN     NaN         NaN               NaN
# 3              NaN  NaN    NaN     NaN         NaN               NaN
# 4              NaN  NaN    NaN     NaN         NaN               NaN
#
#   operating_system_version browser_version month session
# 0                      NaN             NaN     5       0
# 1                      NaN             NaN     5       1
# 2                      NaN             NaN     5       2
# 3                      NaN             NaN     5       3
# 4                      NaN             NaN     5       4
#
# [5 rows x 25 columns]

# %%
es = ft.EntitySet(id = 'person')
es = es.entity_from_dataframe(entity_id = 'person_id', dataframe = persons, index = 'person')
es = es.entity_from_dataframe(entity_id = 'session_id', dataframe = df_month, index = 'session')

# %%
r_client_previous = ft.Relationship(es['person_id']['person'],
                                    es['session_id']['person'])

es = es.add_relationship(r_client_previous)

# %%
# %time features, feature_names = ft.dfs(entityset=es, target_entity='person_id', max_depth = 2)
# Out:
# CPU times: user 5min 1s, sys: 1.46 s, total: 5min 3s
# Wall time: 5min

# %%
features.head()
# Out:
#           SUM(session_id.sku)  SUM(session_id.month)  STD(session_id.sku)  \
# person
# 0008ed71              19124.0                   15.0          2626.717787
# 00091926              13831.0                   10.0            20.506097
# 00091a7a                  0.0                    0.0                  NaN
# 000ba417              22760.0                   30.0          1881.624901
# 000c79fe               9944.0                    5.0                  NaN
#
#           STD(session_id.month)  MAX(session_id.sku)  MAX(session_id.month)  \
# person
# 0008ed71                    0.0               8247.0                    5.0
# 00091926                    0.0               6930.0                    5.0
# 00091a7a                    NaN                  NaN                    NaN
# 000ba417                    0.0               7631.0                    5.0
# 000c79fe                    NaN               9944.0                    5.0
#
#           SKEW(session_id.sku)  SKEW(session_id.month)  MIN(session_id.sku)  \
# person
# 0008ed71             -1.577862                     0.0               3372.0
# 00091926                   NaN                     NaN               6901.0
# 00091a7a                   NaN                     NaN                  NaN
# 000ba417              2.440513                     0.0               2987.0
# 000c79fe                   NaN                     NaN               9944.0
#
#           MIN(session_id.month)  MEAN(session_id.sku)  \
# person
# 0008ed71                    5.0           6374.666667
# 00091926                    5.0           6915.500000
# 00091a7a                    NaN                   NaN
# 000ba417                    5.0           3793.333333
# 000c79fe                    5.0           9944.000000
#
#                             ...                     \
# person                      ...
# 0008ed71                    ...
# 00091926                    ...
# 00091a7a                    ...
# 000ba417                    ...
# 000c79fe                    ...
#
#           MODE(session_id.WEEKDAY(campaign_source))  \
# person
# 0008ed71                                        NaN
# 00091926                                        NaN
# 00091a7a                                        NaN
# 000ba417                                        NaN
# 000c79fe                                        NaN
#
#           MODE(session_id.WEEKDAY(search_engine))  \
# person
# 0008ed71                                      NaN
# 00091926                                      NaN
# 00091a7a                                      NaN
# 000ba417                                      NaN
# 000c79fe                                      NaN
#
#           MODE(session_id.WEEKDAY(channel))  \
# person
# 0008ed71                                NaN
# 00091926                                NaN
# 00091a7a                                NaN
# 000ba417                                NaN
# 000c79fe                                NaN
#
#           MODE(session_id.WEEKDAY(new_vs_returning))  \
# person
# 0008ed71                                         NaN
# 00091926                                         NaN
# 00091a7a                                         NaN
# 000ba417                                         NaN
# 000c79fe                                         NaN
#
#           MODE(session_id.WEEKDAY(city))  MODE(session_id.WEEKDAY(region))  \
# person
# 0008ed71                             NaN                               NaN
# 00091926                             NaN                               NaN
# 00091a7a                             NaN                               NaN
# 000ba417                             NaN                               NaN
# 000c79fe                             NaN                               NaN
#
#           MODE(session_id.WEEKDAY(country))  \
# person
# 0008ed71                                NaN
# 00091926                                NaN
# 00091a7a                                NaN
# 000ba417                                NaN
# 000c79fe                                NaN
#
#          MODE(session_id.WEEKDAY(device_type))  \
# person
# 0008ed71                                   NaN
# 00091926                                   NaN
# 00091a7a                                   NaN
# 000ba417                                   NaN
# 000c79fe                                   NaN
#
#          MODE(session_id.WEEKDAY(screen_resolution))  \
# person
# 0008ed71                                         NaN
# 00091926                                         NaN
# 00091a7a                                         NaN
# 000ba417                                         NaN
# 000c79fe                                         NaN
#
#          MODE(session_id.WEEKDAY(operating_system_version))  \
# person
# 0008ed71                                                NaN
# 00091926                                                NaN
# 00091a7a                                                NaN
# 000ba417                                                NaN
# 000c79fe                                                NaN
#
#          MODE(session_id.WEEKDAY(browser_version))
# person
# 0008ed71                                       NaN
# 00091926                                       NaN
# 00091a7a                                       NaN
# 000ba417                                       NaN
# 000c79fe                                       NaN
#
# [5 rows x 155 columns]

# %%
features['person'] = features.index
features = features.reset_index(drop=True)
features.head()
# Out:
#    SUM(session_id.sku)  SUM(session_id.month)  STD(session_id.sku)  \
# 0              19124.0                   15.0          2626.717787
# 1              13831.0                   10.0            20.506097
# 2                  0.0                    0.0                  NaN
# 3              22760.0                   30.0          1881.624901
# 4               9944.0                    5.0                  NaN
#
#    STD(session_id.month)  MAX(session_id.sku)  MAX(session_id.month)  \
# 0                    0.0               8247.0                    5.0
# 1                    0.0               6930.0                    5.0
# 2                    NaN                  NaN                    NaN
# 3                    0.0               7631.0                    5.0
# 4                    NaN               9944.0                    5.0
#
#    SKEW(session_id.sku)  SKEW(session_id.month)  MIN(session_id.sku)  \
# 0             -1.577862                     0.0               3372.0
# 1                   NaN                     NaN               6901.0
# 2                   NaN                     NaN                  NaN
# 3              2.440513                     0.0               2987.0
# 4                   NaN                     NaN               9944.0
#
#    MIN(session_id.month)  MEAN(session_id.sku)    ...     \
# 0                    5.0           6374.666667    ...
# 1                    5.0           6915.500000    ...
# 2                    NaN                   NaN    ...
# 3                    5.0           3793.333333    ...
# 4                    5.0           9944.000000    ...
#
#    MODE(session_id.WEEKDAY(search_engine))  MODE(session_id.WEEKDAY(channel))  \
# 0                                      NaN                                NaN
# 1                                      NaN                                NaN
# 2                                      NaN                                NaN
# 3                                      NaN                                NaN
# 4                                      NaN                                NaN
#
#    MODE(session_id.WEEKDAY(new_vs_returning))  MODE(session_id.WEEKDAY(city))  \
# 0                                         NaN                             NaN
# 1                                         NaN                             NaN
# 2                                         NaN                             NaN
# 3                                         NaN                             NaN
# 4                                         NaN                             NaN
#
#    MODE(session_id.WEEKDAY(region))  MODE(session_id.WEEKDAY(country))  \
# 0                               NaN                                NaN
# 1                               NaN                                NaN
# 2                               NaN                                NaN
# 3                               NaN                                NaN
# 4                               NaN                                NaN
#
#    MODE(session_id.WEEKDAY(device_type))  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
#
#   MODE(session_id.WEEKDAY(screen_resolution))  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
#
#   MODE(session_id.WEEKDAY(operating_system_version))  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   MODE(session_id.WEEKDAY(browser_version))    person
# 0                                       NaN  0008ed71
# 1                                       NaN  00091926
# 2                                       NaN  00091a7a
# 3                                       NaN  000ba417
# 4                                       NaN  000c79fe
#
# [5 rows x 156 columns]

# %%
features, feature_names = ft.encode_features(features, feature_names)

# %%
features.head()
# Out:
#    SUM(session_id.sku)  SUM(session_id.month)  STD(session_id.sku)  \
# 0              19124.0                   15.0          2626.717787
# 1              13831.0                   10.0            20.506097
# 2                  0.0                    0.0                  NaN
# 3              22760.0                   30.0          1881.624901
# 4               9944.0                    5.0                  NaN
#
#    STD(session_id.month)  MAX(session_id.sku)  MAX(session_id.month)  \
# 0                    0.0               8247.0                    5.0
# 1                    0.0               6930.0                    5.0
# 2                    NaN                  NaN                    NaN
# 3                    0.0               7631.0                    5.0
# 4                    NaN               9944.0                    5.0
#
#    SKEW(session_id.sku)  SKEW(session_id.month)  MIN(session_id.sku)  \
# 0             -1.577862                     0.0               3372.0
# 1                   NaN                     NaN               6901.0
# 2                   NaN                     NaN                  NaN
# 3              2.440513                     0.0               2987.0
# 4                   NaN                     NaN               9944.0
#
#    MIN(session_id.month)  MEAN(session_id.sku)    ...     \
# 0                    5.0           6374.666667    ...
# 1                    5.0           6915.500000    ...
# 2                    NaN                   NaN    ...
# 3                    5.0           3793.333333    ...
# 4                    5.0           9944.000000    ...
#
#    MODE(session_id.WEEKDAY(search_engine)) is unknown  \
# 0                                                  1
# 1                                                  1
# 2                                                  1
# 3                                                  1
# 4                                                  1
#
#    MODE(session_id.WEEKDAY(channel)) is unknown  \
# 0                                             1
# 1                                             1
# 2                                             1
# 3                                             1
# 4                                             1
#
#    MODE(session_id.WEEKDAY(new_vs_returning)) is unknown  \
# 0                                                  1
# 1                                                  1
# 2                                                  1
# 3                                                  1
# 4                                                  1
#
#    MODE(session_id.WEEKDAY(city)) is unknown  \
# 0                                          1
# 1                                          1
# 2                                          1
# 3                                          1
# 4                                          1
#
#    MODE(session_id.WEEKDAY(region)) is unknown  \
# 0                                            1
# 1                                            1
# 2                                            1
# 3                                            1
# 4                                            1
#
#    MODE(session_id.WEEKDAY(country)) is unknown  \
# 0                                             1
# 1                                             1
# 2                                             1
# 3                                             1
# 4                                             1
#
#    MODE(session_id.WEEKDAY(device_type)) is unknown  \
# 0                                                 1
# 1                                                 1
# 2                                                 1
# 3                                                 1
# 4                                                 1
#
#    MODE(session_id.WEEKDAY(screen_resolution)) is unknown  \
# 0                                                  1
# 1                                                  1
# 2                                                  1
# 3                                                  1
# 4                                                  1
#
#    MODE(session_id.WEEKDAY(operating_system_version)) is unknown  \
# 0                                                  1
# 1                                                  1
# 2                                                  1
# 3                                                  1
# 4                                                  1
#
#    MODE(session_id.WEEKDAY(browser_version)) is unknown    person
# 0                                                  1     0008ed71
# 1                                                  1     00091926
# 2                                                  1     00091a7a
# 3                                                  1     000ba417
# 4                                                  1     000c79fe
#
# [5 rows x 209 columns]

# %%
features['diferencia 5'].fillna(int(features['diferencia 5'].median()), inplace = True)
features['DAY(last month 5)'].fillna(int(features['DAY(last month 5)'].mean()), inplace = True)
features['DAY(first month 5)'].fillna(int(features['DAY(first month 5)'].mean()), inplace = True)
features['WEEKDAY(last month 5)'].fillna(int(features['WEEKDAY(last month 5)'].mean()), inplace = True)
features['WEEKDAY(first month 5)'].fillna(int(features['WEEKDAY(first month 5)'].mean()), inplace = True)
lista = ['diferencia 5','DAY(last month 5)', 'DAY(first month 5)','WEEKDAY(last month 5)','WEEKDAY(first month 5)','person']

features = features[lista]

# %%
person = (features.loc[features['diferencia 5'].isnull()])['person']

# %%
features = persons.merge(features, on='person', how='left')

# %%
features.shape
# Out:
# (38829, 6)

# %%
features.to_csv('date.csv')

# %% [markdown]
# ## XGboost entrenamiento

# %%
df_train = df_labels.merge(features , left_on='person', right_on='person' , how='left')
print(df_train.shape)
df_train.head()
# Out:
# (19414, 12)
#      person  label  MAX(session_id.sku)  MEAN(session_id.sku)  \
# 0  0566e9c1      0               2680.0                2680.0
# 1  6ec7ee77      0                  NaN                   NaN
# 2  abe7a2fb      0               2832.0                2832.0
# 3  34728364      0                  NaN                   NaN
# 4  87ed62de      0               6411.0                6411.0
#
#    MIN(session_id.sku)  MODE(session_id.DAY(timestamp)) is unknown  \
# 0               2680.0                                           0
# 1                  NaN                                           1
# 2               2832.0                                           0
# 3                  NaN                                           1
# 4               6411.0                                           0
#
#    NUM_UNIQUE(session_id.condition)  NUM_UNIQUE(session_id.storage)  \
# 0                               1.0                             1.0
# 1                               NaN                             NaN
# 2                               1.0                             1.0
# 3                               NaN                             NaN
# 4                               1.0                             1.0
#
#    SKEW(session_id.sku)  STD(session_id.sku)  SUM(session_id.NUMWORDS(skus))  \
# 0                   NaN                  NaN                             1.0
# 1                   NaN                  NaN                             0.0
# 2                   NaN                  NaN                             1.0
# 3                   NaN                  NaN                             0.0
# 4                   NaN                  0.0                             2.0
#
#    SUM(session_id.sku)
# 0               2680.0
# 1                  0.0
# 2               2832.0
# 3                  0.0
# 4              12822.0

# %%
#df_train_1 = df_train.loc[df_train['label'] == 1]
#df_train_0 = df_train.loc[df_train['label'] == 0]

#df_train2 = pd.concat([df_train_1, df_train_0.sample(2000)])

# %% [markdown]
# Los labels me dan mi set para entrenar, los que no se encuentran en labels tengo que predecirlos

# %% [markdown]
# Si ven aca, de la columna label en adelante tenemos los features.

# %%
X, y = df_train.iloc[:,2:],df_train.iloc[:,1]
X.head()
# Out:
#    MAX(session_id.sku)  MEAN(session_id.sku)  MIN(session_id.sku)  \
# 0               2680.0                2680.0               2680.0
# 1                  NaN                   NaN                  NaN
# 2               2832.0                2832.0               2832.0
# 3                  NaN                   NaN                  NaN
# 4               6411.0                6411.0               6411.0
#
#    MODE(session_id.DAY(timestamp)) is unknown  \
# 0                                           0
# 1                                           1
# 2                                           0
# 3                                           1
# 4                                           0
#
#    NUM_UNIQUE(session_id.condition)  NUM_UNIQUE(session_id.storage)  \
# 0                               1.0                             1.0
# 1                               NaN                             NaN
# 2                               1.0                             1.0
# 3                               NaN                             NaN
# 4                               1.0                             1.0
#
#    SKEW(session_id.sku)  STD(session_id.sku)  SUM(session_id.NUMWORDS(skus))  \
# 0                   NaN                  NaN                             1.0
# 1                   NaN                  NaN                             0.0
# 2                   NaN                  NaN                             1.0
# 3                   NaN                  NaN                             0.0
# 4                   NaN                  0.0                             2.0
#
#    SUM(session_id.sku)
# 0               2680.0
# 1                  0.0
# 2               2832.0
# 3                  0.0
# 4              12822.0

# %% [markdown]
# Separamos los datos para hacer xgboost de la siguiente forma
#
#
# |Variable |Contiene|
# |------------------------|-----------------------------------------------------|
# |X| features que usa xgboost son solo numeros es decir que sacamos a la persona   |
# |y| label de cada persona|

# %% [markdown]
# ## Xgboost
#
# Para evaluar usen esta medida que me da valores muy parecidos a los de kaggle, para hacer las predicciones usen el otro

# %%
my_classifier1 = xgb.XGBClassifier(objective ='reg:linear', 
                colsample_bytree = 1, learning_rate = 0.1,
                max_depth = 6,
                subsample = 0.8,
                gamma = 1,
                n_estimators = 10)

# %% [markdown]
# Este es el arbol con sus hiperparametros

# %%
X_train, X_test, y_train, y_test = \
    train_test_split(X, y, test_size=0.2, random_state=123)

# %% [markdown]
# Aca vuelvo a separar los datos para poder realizar una metrica interna y ver masomenos como performan las cosas que hago

# %% [markdown]
# Obtengo las personas a predecir!

# %%
X_predict = features.loc[features['person'].isin(persons_to_predict['person'])]
X_predict.head()
# Out:
#    MAX(session_id.sku)  MEAN(session_id.sku)  MIN(session_id.sku)  \
# 1               6930.0           6915.500000               6901.0
# 2                  NaN                   NaN                  NaN
# 3               7631.0           3793.333333               2987.0
# 5               3360.0           3360.000000               3360.0
# 6               8541.0           8541.000000               8541.0
#
#    MODE(session_id.DAY(timestamp)) is unknown  \
# 1                                           1
# 2                                           1
# 3                                           0
# 5                                           1
# 6                                           0
#
#    NUM_UNIQUE(session_id.condition)  NUM_UNIQUE(session_id.storage)  \
# 1                               2.0                             1.0
# 2                               NaN                             NaN
# 3                               2.0                             1.0
# 5                               1.0                             1.0
# 6                               1.0                             1.0
#
#    SKEW(session_id.sku)  STD(session_id.sku)  SUM(session_id.NUMWORDS(skus))  \
# 1                   NaN            20.506097                             2.0
# 2                   NaN                  NaN                             0.0
# 3              2.440513          1881.624901                             6.0
# 5                   NaN                  NaN                             1.0
# 6                   NaN                  NaN                             1.0
#
#    SUM(session_id.sku)    person
# 1              13831.0  00091926
# 2                  0.0  00091a7a
# 3              22760.0  000ba417
# 5               3360.0  000e4d9e
# 6               8541.0  000e619d

# %% [markdown]
# Necesito tener el mismo dataframe que tenia cuando lo entrene pero ahora para predecir, en este caso <b>X</b>

# %%
my_classifier1.fit(X_train,y_train)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=1, learning_rate=0.1, max_delta_step=0,
#        max_depth=6, min_child_weight=1, missing=None, n_estimators=10,
#        n_jobs=1, nthread=None, objective='reg:linear', random_state=0,
#        reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#        silent=True, subsample=0.8)

# %% [markdown]
# Entreno al arbol!

# %%
from sklearn.metrics import roc_auc_score
roc_auc_score(y_test,  my_classifier1.predict_proba(X_test)[:,1])
# Out:
# 0.7944345493014471

# %% [markdown]
# Obtengo un resultado con los que separe para el test mas arriba en :
# ```python
#     X_train, X_test, y_train, y_test = \
#     train_test_split(X, y, test_size=0.2, random_state=123)
#     ```
# ###### Lo que hace es sacar las predicciones para X_test y evaluarlos con y_test

# %%
entrie = my_classifier1.predict_proba(X_predict.iloc[:,1:])[:,1]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-137-9d2a507f3da4> in <module>
# ----> 1 entrie = my_classifier1.predict_proba(X_predict.iloc[:,1:])[:,1]
#
# ~/.local/lib/python3.6/site-packages/xgboost/sklearn.py in predict_proba(self, data, ntree_limit)
#     627             a numpy array with the probability of each data example being of a given class.
#     628         """
# --> 629         test_dmatrix = DMatrix(data, missing=self.missing, nthread=self.n_jobs)
#     630         if ntree_limit is None:
#     631             ntree_limit = getattr(self, "best_ntree_limit", 0)
#
# ~/.local/lib/python3.6/site-packages/xgboost/core.py in __init__(self, data, label, missing, weight, silent, feature_names, feature_types, nthread)
#     342         data, feature_names, feature_types = _maybe_pandas_data(data,
#     343                                                                 feature_names,
# --> 344                                                                 feature_types)
#     345
#     346         data, feature_names, feature_types = _maybe_dt_data(data,
#
# ~/.local/lib/python3.6/site-packages/xgboost/core.py in _maybe_pandas_data(data, feature_names, feature_types)
#     212         msg = """DataFrame.dtypes for data must be int, float or bool.
#     213                 Did not expect the data types in fields """
# --> 214         raise ValueError(msg + ', '.join(bad_fields))
#     215
#     216     if feature_names is None:
#
# ValueError: DataFrame.dtypes for data must be int, float or bool.
#                 Did not expect the data types in fields person

# %% [markdown]
# Valores a subir a kaggle, lo que sigue son transformaciones a dataframe para convertirlo en csv, y algunas cosas para darme idea tipo por donde andan los valores normales en los resultados que me da

# %%
X_predict['label'] = entrie
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-138-f3b5001ed033> in <module>
# ----> 1 X_predict['label'] = entrie
#
# NameError: name 'entrie' is not defined

# %%
df_entrie = X_predict[['person', 'label']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-115-6605e76cbc8b> in <module>
# ----> 1 df_entrie = X_predict[['person', 'label']]
#
# ~/.local/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2680         if isinstance(key, (Series, np.ndarray, Index, list)):
#    2681             # either boolean or fancy integer index
# -> 2682             return self._getitem_array(key)
#    2683         elif isinstance(key, DataFrame):
#    2684             return self._getitem_frame(key)
#
# ~/.local/lib/python3.6/site-packages/pandas/core/frame.py in _getitem_array(self, key)
#    2724             return self._take(indexer, axis=0)
#    2725         else:
# -> 2726             indexer = self.loc._convert_to_indexer(key, axis=1)
#    2727             return self._take(indexer, axis=1)
#    2728
#
# ~/.local/lib/python3.6/site-packages/pandas/core/indexing.py in _convert_to_indexer(self, obj, axis, is_setter)
#    1325                 if mask.any():
#    1326                     raise KeyError('{mask} not in index'
# -> 1327                                    .format(mask=objarr[mask]))
#    1328
#    1329                 return com._values_from_object(indexer)
#
# KeyError: "['label'] not in index"

# %%
df_entrie.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-93-06fd8b37ba06> in <module>
# ----> 1 df_entrie.head()
#
# NameError: name 'df_entrie' is not defined

# %%
df_entrie.to_csv(path_or_buf = 'submit_kaggle.csv', index = False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-94-8314ef4b9059> in <module>
# ----> 1 df_entrie.to_csv(path_or_buf = 'submit_kaggle.csv', index = False)
#
# NameError: name 'df_entrie' is not defined

# %%
df_entrie.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-95-31c3f61be906> in <module>
# ----> 1 df_entrie.shape
#
# NameError: name 'df_entrie' is not defined

# %% [markdown]
#  # Random Forest feature importance
#    - Algoritmo usado para sacar importancia de los features y ver cuales no nos estan sirviendo al modelo
#  #### Es parecido a lo que hice en xgboost con algunas cosas magicas, que use para ponerlo en df y ver resultados
#
#   ## NOTAR :
#    - Que use la X de xgboost
#    - Y que el codigo abajo del dataframe comentado puede funcionar para separar los df pidiendo que nos deje las columnas esas

# %%
X = X.fillna(0)

# %%
from sklearn.ensemble import RandomForestRegressor
import numpy as np
#Load boston housing dataset as an example

names = X.columns
rf = RandomForestRegressor()
rf.fit(X, y)
zipped = zip(map(lambda x: round(x, 4), rf.feature_importances_), names)
feature = sorted(zipped, key=lambda x: x[1])

# %%
feat_importance = pd.DataFrame(feature, columns=['importance', 'feature'])
feat_importance.sort_values('importance', ascending=False).head(100)
# Out:
#    importance               feature
# 5      0.3396   SUM(session_id.sku)
# 2      0.2060   MIN(session_id.sku)
# 1      0.1702  MEAN(session_id.sku)
# 0      0.1234   MAX(session_id.sku)
# 4      0.0994   STD(session_id.sku)
# 3      0.0614  SKEW(session_id.sku)

# %%
feat_importance =feat_importance.loc[feat_importance['importance'].isin(feat_importance['importance'].nlargest(6))]
feats_servibles = feat_importance['feature'].tolist()
feats_servibles.append('person')
features_importantes = features[feats_servibles]

# %%
features_importantes.head()
# Out:
#    SUM(session_id.sku)    person
# 0              19124.0  0008ed71
# 1              13831.0  00091926
# 2                  0.0  00091a7a
# 3              22760.0  000ba417
# 4               9944.0  000c79fe

# %%
df_month.shape
# Out:
# (1713920, 24)

# %%
df.shape
# Out:
# (2341681, 24)

# %%
features.to_csv('new_features.csv', index=False)
# Out:
# Exception ignored in: <bound method DMatrix.__del__ of <xgboost.core.DMatrix object at 0x7fb66d091400>>
# Traceback (most recent call last):
#   File "/home/amaherok/.local/lib/python3.6/site-packages/xgboost/core.py", line 482, in __del__
#     if self.handle is not None:
# AttributeError: 'DMatrix' object has no attribute 'handle'
# Exception ignored in: <bound method DMatrix.__del__ of <xgboost.core.DMatrix object at 0x7fb66cf44f98>>
# Traceback (most recent call last):
#   File "/home/amaherok/.local/lib/python3.6/site-packages/xgboost/core.py", line 482, in __del__
#     if self.handle is not None:
# AttributeError: 'DMatrix' object has no attribute 'handle'
# Exception ignored in: <bound method DMatrix.__del__ of <xgboost.core.DMatrix object at 0x7fb66cf58ba8>>
# Traceback (most recent call last):
#   File "/home/amaherok/.local/lib/python3.6/site-packages/xgboost/core.py", line 482, in __del__
#     if self.handle is not None:
# AttributeError: 'DMatrix' object has no attribute 'handle'
